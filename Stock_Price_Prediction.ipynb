# %% [markdown]
# <a href="https://colab.research.google.com/github/Baghrai-Beshra/Stock-Price-Prediction/blob/main/Stock_Price_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Description: This is use an artificial recurrent neural network called Long Temp Memory (LSTM) to prdict the closing
#             stock price of a corporation (Apple Inc.) using the past 60 day stock price.

# %%
#Import the libraries
import math
import pandas_datareader as web
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
# !pip install yfinance

# %%
#Import the libraries
import math
import yfinance as yf  # Import yfinance instead of pandas_datareader
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

#Get the stock quote
# Use yf.download instead of web.DataReader
df = yf.download("AAPL", start="2012-01-01", end="2019-12-17")
#Show the data
df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2012-01-03  14.621429  14.732143  14.607143  14.686786  12.402627  302220800
# 2012-01-04  14.642857  14.810000  14.617143  14.765714  12.469282  260022000
# 2012-01-05  14.819643  14.948214  14.738214  14.929643  12.607713  271269600
# 2012-01-06  14.991786  15.098214  14.972143  15.085714  12.739516  318292800
# 2012-01-09  15.196429  15.276786  15.048214  15.061786  12.719306  394024400
# ...               ...        ...        ...        ...        ...        ...
# 2019-12-10  67.150002  67.517502  66.464996  67.120003  65.143265   90420400
# 2019-12-11  67.202499  67.775002  67.125000  67.692497  65.698898   78756800
# 2019-12-12  66.945000  68.139999  66.830002  67.864998  65.866310  137310400
# 2019-12-13  67.864998  68.824997  67.732498  68.787498  66.761650  133587600
# ...

# %%
#Get the number of rows and columns in the dataset

df.shape
# Out:
# (2002, 6)

# %%
#Visualize the closing price history
plt.figure(figsize=(16,8))
plt.title('Close Price History')
plt.plot(df['Close'])
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)',fontsize=18)
plt.show()

# %%
# Create a new dataframe with only the 'Close column
data=df.filter(['Close'])
#Convert the dataframe to a numpy  array
dataset=data.values
#Get the number of rows to train the model on
training_data_len=math.ceil(len(dataset)* .8)
training_data_len
# Out:
# 1602

# %%
#Scale the data
scaler=MinMaxScaler(feature_range=(0,1))
scaled_data=scaler.fit_transform(dataset)

scaled_data
# Out:
# array([[0.0131974 ],
#        [0.01460639],
#        [0.01753278],
#        ...,
#        [0.96251174],
#        [0.97897982],
#        [1.        ]])

# %%
#Create the training data set
#Create the scaled traing data set
train_data=scaled_data[0:training_data_len, :]
#Split the data into x_train and y_train data set
x_train=[]
y_train=[]

for i in range(60, len(train_data)):
  x_train.append(train_data[i-60:i,0])
  y_train.append(train_data[i,0])

  if i<=60:
    print(x_train)
    print(y_train)
    print()
# Out:
# [array([0.0131974 , 0.01460639, 0.01753278, 0.0203189 , 0.01989174,
#        0.02085445, 0.02041453, 0.01967497, 0.01866762, 0.02178528,
#        0.02459691, 0.02372983, 0.01898002, 0.02351306, 0.01905016,
#        0.03578601, 0.03449178, 0.0361813 , 0.03983449, 0.0420468 ,
#        0.04186191, 0.04117973, 0.04408699, 0.04682209, 0.04992063,
#        0.05492545, 0.06543874, 0.06559812, 0.0714509 , 0.07582451,
#        0.06830775, 0.07120224, 0.07114487, 0.07926096, 0.07810697,
#        0.08024277, 0.08408086, 0.08621669, 0.0923691 , 0.0968511 ,
#        0.09814534, 0.09859802, 0.09093461, 0.08908567, 0.08935984,
#        0.09656423, 0.09859166, 0.10294617, 0.1132108 , 0.12690551,
#        0.12434252, 0.12434889, 0.13425015, 0.13734869, 0.13514271,
#        0.13312806, 0.13103049, 0.13799896, 0.14278065, 0.14478257])]
# [0.139835129205152]

# %%
#Create the training data set
#Create the scaled traing data set
train_data=scaled_data[0:training_data_len, :]
#Split the data into x_train and y_train data set
x_train=[]
y_train=[]

for i in range(60, len(train_data)):
  x_train.append(train_data[i-60:i,0])
  y_train.append(train_data[i,0])

  if i<=61:
    print(x_train)
    print(y_train)
    print()
# Out:
# [array([0.0131974 , 0.01460639, 0.01753278, 0.0203189 , 0.01989174,
#        0.02085445, 0.02041453, 0.01967497, 0.01866762, 0.02178528,
#        0.02459691, 0.02372983, 0.01898002, 0.02351306, 0.01905016,
#        0.03578601, 0.03449178, 0.0361813 , 0.03983449, 0.0420468 ,
#        0.04186191, 0.04117973, 0.04408699, 0.04682209, 0.04992063,
#        0.05492545, 0.06543874, 0.06559812, 0.0714509 , 0.07582451,
#        0.06830775, 0.07120224, 0.07114487, 0.07926096, 0.07810697,
#        0.08024277, 0.08408086, 0.08621669, 0.0923691 , 0.0968511 ,
#        0.09814534, 0.09859802, 0.09093461, 0.08908567, 0.08935984,
#        0.09656423, 0.09859166, 0.10294617, 0.1132108 , 0.12690551,
#        0.12434252, 0.12434889, 0.13425015, 0.13734869, 0.13514271,
#        0.13312806, 0.13103049, 0.13799896, 0.14278065, 0.14478257])]
# [0.139835129205152]
#
# [array([0.0131974 , 0.01460639, 0.01753278, 0.0203189 , 0.01989174,
#        0.02085445, 0.02041453, 0.01967497, 0.01866762, 0.02178528,
# ...

# %%
#Convert thex_train and y_train to numpy array
x_train,y_train=np.array(x_train), np.array(y_train)

# %%
#Reshape the data
x_train.shape
# Out:
# (1542, 60)

# %%
#Reshape the data
x_train=np.reshape(x_train, (x_train.shape[0],x_train.shape[1],1))
x_train.shape
# Out:
# (1542, 60, 1)

# %%
#Build the LSTM model
model=Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(x_train.shape[1],1)))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
#Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
#Train the model
model.fit(x_train, y_train, batch_size=1, epochs=1)
# Out:
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 50s 30ms/step - loss: 0.0025

# %%
#Create the testing data set
#Create a new array containing scaled values from index  1543 to 2003
test_data=scaled_data[training_data_len -60:, :]
#Create the data sets x_test and y_test
x_test=[]
y_test=dataset[training_data_len: , :]
for i in range(60, len(test_data)):
  x_test.append(test_data[i-60:i, 0])

# %%
#Convert the data into a numpy array
x_test=np.array(x_test)

# %%
#Reshape the data
x_test=np.reshape(x_test, (x_test.shape[0],x_test.shape[1],1))

# %%
#Get the model predicted price values
predictions=model.predict(x_test)
predictions=scaler.inverse_transform(predictions)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 125ms/step

# %%
#Get the root men square error (RMSE)
rmse=np.sqrt(np.mean(predictions-y_test)**2)
rmse
# Out:
# 4.045744953155517

# %%
#Plot the data
train=data[:training_data_len]
valid=data[training_data_len:]
valid['Predictions']=predictions # Changed 'predictions' to 'Predictions' to match plotting code
#Visualize the data
plt.figure(figsize=(16,8))
plt.title('Model')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.plot(train['Close'])
plt.plot(valid[['Close','Predictions']])
plt.legend(['Train', 'Val', 'Predictions'], loc='lower right')
plt.show()
# Out:
# <ipython-input-43-efdde1903580>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['Predictions']=predictions # Changed 'predictions' to 'Predictions' to match plotting code

# %%
#Show the valid predictive prices
valid
# Out:
#                 Close  predictions
# Date
# 2018-05-16  47.044998    43.418118
# 2018-05-17  46.747501    43.561031
# 2018-05-18  46.577499    43.633572
# 2018-05-21  46.907501    43.646420
# 2018-05-22  46.790001    43.656281
# ...               ...          ...
# 2019-12-10  67.120003    59.585140
# 2019-12-11  67.692497    59.720913
# 2019-12-12  67.864998    59.900745
# 2019-12-13  68.787498    60.097210
# 2019-12-16  69.964996    60.363674
#
# [400 rows x 2 columns]

# %%
#Get the quote
apple_quote = web.DataReader('AAPL', data_source='yahoo', start='2012-01-01', end='2019-12-17')
#Create a new dataframe
new_df=apple_quote.filter(['Close'])
#Get the last 60 days closing price values and convert the dtaframe to an array
last_60_days=new_df[-60:].values
last_60_days_scaled=scaler.transform(last_60_days)
#Create an empty list
X_test=[]
#Append the past 60 days
X_test.append(last_60_days_scaled)
#Convert the next X_tset data to a numpy array
X_test=np.array(X_test)
#Reshape the data
X_test=np.reshape(X_test, (X_test.shape[0], X_test.shape[1],1))
#Get predicted scaled price
pred_price=model.predict(X_test)
#undo the scaling
pred_price=scaler.inverse_transform(pred_price)
print(pred_price)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-56-3c17af9df73d> in <cell line: 2>()
#       1 #Get the quote
# ----> 2 apple_quote = web.DataReader('AAPL', data_source='yahoo', start='2012-01-01', end='2019-12-17')
#       3 #Create a new dataframe
#       4 new_df=apple_quote.filter(['Close'])
#       5 #Get the last 60 days closing price values and convert the dtaframe to an array
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     211                     raise TypeError(msg)
#     212                 kwargs[new_arg_name] = new_arg_value
# --> 213             return func(*args, **kwargs)
#     214
#     215         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas_datareader/data.py in DataReader(name, data_source, start, end, retry_count, pause, session, api_key)
# ...

# %%
# !pip install yfinance
import yfinance as yf
import pandas as pd


#Get the quote
# apple_quote = web.DataReader('AAPL', data_source='yahoo', start='2012-01-01', end='2019-12-17')
# Instead of using pandas_datareader, use yfinance to get the data
apple_quote = yf.download('AAPL', start='2012-01-01', end='2019-12-17')

#Create a new dataframe
new_df=apple_quote.filter(['Close'])
#Get the last 60 days closing price values and convert the dtaframe to an array
last_60_days=new_df[-60:].values
last_60_days_scaled=scaler.transform(last_60_days)
#Create an empty list
X_test=[]
#Append the past 60 days
X_test.append(last_60_days_scaled)
#Convert the next X_tset data to a numpy array
X_test=np.array(X_test)
#Reshape the data
X_test=np.reshape(X_test, (X_test.shape[0], X_test.shape[1],1))
#Get predicted scaled price
pred_price=model.predict(X_test)
#undo the scaling
pred_price=scaler.inverse_transform(pred_price)
print(pred_price)
# Out:
# ...
# [*********************100%***********************]  1 of 1 completed
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# [[60.74008]]

# %%
#Get the quote
apple_quote2 = web.DataReader('AAPL', data_source='yahoo', start='2019-12-18', end='2019-12-18')
print(apple_quote2['Close'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-61-6f73443f5bb1> in <cell line: 2>()
#       1 #Get the quote
# ----> 2 apple_quote2 = web.DataReader('AAPL', data_source='yahoo', start='2019-12-18', end='2019-12-18')
#       3 print(apple_quote2['Close'])
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     211                     raise TypeError(msg)
#     212                 kwargs[new_arg_name] = new_arg_value
# --> 213             return func(*args, **kwargs)
#     214
#     215         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas_datareader/data.py in DataReader(name, data_source, start, end, retry_count, pause, session, api_key)
#     377             pause=pause,
#     378             session=session,
# --> 379         ).read()
#     380
# ...

# %%
# !pip install yfinance
import yfinance as yf
import pandas as pd

#Get the quote
# apple_quote2 = web.DataReader('AAPL', data_source='yahoo', start='2019-12-18', end='2019-12-18')
# Instead of using pandas_datareader, use yfinance to get the data
apple_quote2 = yf.download('AAPL', start='2019-12-18', end='2019-12-18')

print(apple_quote2['Close'])
# Out:
# ...
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AAPL']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2019-12-18 -> 2019-12-18)')
# Series([], Name: Close, dtype: float64)
